# %%
import pandas as pd
pd.set_option("display.max_rows", 1000
             )

# %%
tester = pd.read_pickle('./testdf.pkl')

# %%
tester
# Out:
#                        players   winloss  wins  losses  win pct  rank2021
# 0                 Rafael Nadal  1027-208  1027     208   0.8316       2.0
# 1               Novak Djokovic   961-195   961     195   0.8313       1.0
# 2                   Bjorn Borg   654-140   654     140   0.8237       NaN
# 3                Roger Federer  1247-274  1247     274   0.8199       NaN
# 4                Jimmy Connors  1274-283  1274     283   0.8182       NaN
# 5                 John McEnroe   883-198   883     198   0.8168       NaN
# 6                   Ivan Lendl  1068-242  1068     242   0.8153       NaN
# 7                    Rod Laver   576-146   576     146   0.7978       NaN
# 8                 Pete Sampras   762-222   762     222   0.7744       NaN
# 9                  Andy Murray   678-203   678     203   0.7696       NaN
# 10                Boris Becker   713-214   713     214   0.7691       NaN
# 11             Guillermo Vilas   951-297   951     297   0.7620       NaN
# ...
